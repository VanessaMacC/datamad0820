# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# API endpoint URL
url='https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %%
response = urllib.request.urlopen(url)
results = json.load(response)

flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   AD111A0Q7-A11  STAN SMITH - Baskets basses - footwear white/g...
# 1   LE221N04U-Q11  MILE HIGH SUPER SKINNY - Jeans Skinny - black ...
# 2   LE221G031-K11  ORIGINAL TRUCKER - Veste en jean - soft as but...
# 3   TO121J06O-K11              HOODIE - Sweat à capuche - desert sky
# 4   AN611BA4P-Q11                     Escarpins à plateforme - black
# ..            ...                                                ...
# 79  LA211A0E2-A12         GRADUATE  - Baskets basses - white/natural
# 80  AN611B0C1-Q11                                  Escarpins - black
# 81  AD115O0E4-A11    OZWEEGO - Baskets basses - ftwwht/ftwwht/cblack
# 82  TOB21G01V-K11  VIVIANNE SLIM TRUCKER BXDBS - Veste en jean - ...
# 83  PU111A0FZ-A12  FUTURE RIDER  - Baskets basses - white/gray vi...
#
#                                                 sizes  \
# 0   [36, 38, 40, 42, 36 2/3, 37 1/3, 38 2/3, 39 1/...
# 1   [23x28, 23x30, 24x28, 24x30, 24x32, 25x28, 25x...
# 2                                  [XXS, XS, S, M, L]
# 3                         [XXS, XS, S, M, L, XL, XXL]
# 4                            [36, 37, 38, 39, 40, 41]
# ..                                                ...
# 79     [35.5, 36, 37, 38, 39, 39.5, 40, 40.5, 41, 42]
# 80                           [36, 37, 38, 39, 40, 41]
# 81  [36, 42, 44, 46, 48, 41 1/3, 42 2/3, 43 1/3, 4...
# 82                                    [XXS, XS, S, M]
# 83                             [36, 37, 37.5, 38, 42]
#
#                                               url_key  \
# 0   adidas-originals-stan-smith-baskets-basses-foo...
# 1   levisr-mile-high-super-skinny-jeans-skinny-le2...
# 2   levisr-original-trucker-veste-en-jean-soft-as-...
# 3   tommy-hilfiger-hoodie-sweatshirt-desert-sky-to...
# 4   anna-field-escarpins-compenses-black-an611ba4p...
# ..                                                ...
# 79  lacoste-graduate-baskets-basses-whitenatural-l...
# 80           anna-field-escarpins-black-an611b0c1-q11
# 81  adidas-originals-ozweego-baskets-basses-ad115o...
# 82  tommy-jeans-vivianne-slim-trucker-bxdbs-veste-...
# 83     puma-future-rider-baskets-basses-pu111a0fz-a12
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/566391dd3ffb3feca398e7...  adidas Originals
# 1   [{'path': 'spp-media-p1/df7d6a01a4833214aa11c6...           Levi's®
# 2   [{'path': 'spp-media-p1/b06b79cb3ac83c549f3008...           Levi's®
# 3   [{'path': 'spp-media-p1/bce9b28acba53dd987b6a8...    Tommy Hilfiger
# 4   [{'path': 'spp-media-p1/a00b49ce7d93303c86891e...        Anna Field
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/2e74e97856ee33029c20d4...           Lacoste
# 80  [{'path': 'spp-media-p1/d0d275322cc53141b1e6d4...        Anna Field
# 81  [{'path': 'spp-media-p1/9dc0c2b2aac738598d30aa...  adidas Originals
# 82  [{'path': 'spp-media-p1/bfff1851d4613ea9b92db2...       Tommy Jeans
# 83  [{'path': 'spp-media-p1/309b2108fd5030da8c4dc9...              Puma
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 80  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 81  [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 82  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 83  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        99,95 €           74,95 €
# 1                 []        99,95 €           69,95 €
# 2                 []       119,95 €           83,95 €
# 3                 []        99,95 €           69,95 €
# 4                 []        34,99 €           29,69 €
# ..               ...            ...               ...
# 79                []        89,95 €           62,95 €
# 80                []        33,99 €           30,59 €
# 81                []       119,95 €           83,95 €
# 82                []        99,95 €           74,95 €
# 83                []        89,95 €           71,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only outfits
# 0                                       False     NaN
# 1                                       False     NaN
# 2                                       False     NaN
# 3                                       False     NaN
# 4                                       False     NaN
# ..                                        ...     ...
# 79                                      False     NaN
# 80                                      False     NaN
# 81                                      False     NaN
# 82                                      False     NaN
# 83                                      False     NaN
#
# [84 rows x 18 columns]

# %%
total_pages=results['pagination']['page_count']

df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')
 
df

# He consultado el error y no logro saber qué ocurre
# Out:
# getting page 114 of 892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b1f646de847d> in <module>
#       5     k=84*i
#       6     url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
# ----> 7     response = urllib.request.urlopen(url)
#       8     results = json.load(response)
#       9     flattened_data = json_normalize(results)
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

#The trending brand
df.brand_name.value_counts().index[0]
# Out:
# 'Anna Field'

# %%
#The product(s) with the highest discount
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
df['original_amount']=df['price.original'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['product_group']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# el resultado es:
# Out:
# 'clothing'

# %%
#The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).
total_origin=df1.groupby(['product_group']).sum().original_amount

sum_total_disc=total_disc[total_disc]/total_origin[total_origin]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-e15b8caea206> in <module>
#       2 total_origin=df1.groupby(['product_group']).sum().original_amount
#       3
# ----> 4 sum_total_disc=total_disc[total_disc]/total_origin[total_origin]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     906             return self._get_values(key)
#     907
# --> 908         return self._get_with(key)
#     909
#     910     def _get_with(self, key):
#
# /usr/local/lib/python3.8/site-packages/pandas/core/series.py in _get_with(self, key)
#     946
#     947         # handle the dup indexing case GH#4246
# --> 948         return self.loc[key]
#     949
#     950     def _get_values_tuple(self, key):
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([ 40391.60999999994, 1575.7499999999995, 416.24999999999994,\n              101881.60000000031,  96.76000000000002,  59707.50000000009,\n              1289.1000000000001],\n             dtype='float64', name='product_group')] are in the [index]"
