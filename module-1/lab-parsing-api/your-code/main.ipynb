# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# API endpoint URL
url='https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %%
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   AD111A0Q7-A11  STAN SMITH - Baskets basses - footwear white/g...
# 1   LE221N04U-Q11  MILE HIGH SUPER SKINNY - Jeans Skinny - black ...
# 2   LE221G031-K11  ORIGINAL TRUCKER - Veste en jean - soft as but...
# 3   AN611BA4P-Q11                     Escarpins à plateforme - black
# 4   VA211S03A-Q11       UA OLD SKOOL  - Baskets basses - black/white
# ..            ...                                                ...
# 79  MK151H03O-O12  JET SET TRAVEL CROSSBODY - Sac bandoulière - b...
# 80  EV421I0AQ-B11                                    Pullover - sand
# 81  VE121G0OG-Q11   VMRIA SHORT JACKET - Veste en similicuir - black
# 82  LA211A0E2-A12         GRADUATE  - Baskets basses - white/natural
# 83  TOB21G01V-K11  VIVIANNE SLIM TRUCKER BXDBS - Veste en jean - ...
#
#                                                 sizes  \
# 0   [36, 38, 40, 42, 36 2/3, 37 1/3, 38 2/3, 39 1/...
# 1   [23x28, 23x30, 24x28, 24x30, 24x32, 25x28, 25x...
# 2                                  [XXS, XS, S, M, L]
# 3                            [36, 37, 38, 39, 40, 41]
# 4   [36, 36.5, 37, 38, 38.5, 39, 40, 40.5, 41, 42,...
# ..                                                ...
# 79                                         [One Size]
# 80                                  [XS, S, M, L, XL]
# 81                                      [XS, S, M, L]
# 82  [35.5, 36, 37, 37.5, 38, 39, 39.5, 40, 40.5, 4...
# 83                                 [XXS, XS, S, M, L]
#
#                                               url_key  \
# 0   adidas-originals-stan-smith-baskets-basses-foo...
# 1   levisr-mile-high-super-skinny-jeans-skinny-le2...
# 2   levisr-original-trucker-veste-en-jean-soft-as-...
# 3   anna-field-escarpins-compenses-black-an611ba4p...
# 4        vans-baskets-basses-blackwhite-va211s03a-q11
# ..                                                ...
# 79  michael-michael-kors-jet-set-sac-bandouliere-m...
# 80             evenandodd-pullover-sand-ev421i0aq-b11
# 81  vero-moda-vmria-short-jacket-veste-en-similicu...
# 82  lacoste-graduate-baskets-basses-whitenatural-l...
# 83  tommy-jeans-vivianne-slim-trucker-bxdbs-veste-...
#
#                                                 media            brand_name  \
# 0   [{'path': 'spp-media-p1/566391dd3ffb3feca398e7...      adidas Originals
# 1   [{'path': 'spp-media-p1/df7d6a01a4833214aa11c6...               Levi's®
# 2   [{'path': 'spp-media-p1/b06b79cb3ac83c549f3008...               Levi's®
# 3   [{'path': 'spp-media-p1/a00b49ce7d93303c86891e...            Anna Field
# 4   [{'path': 'spp-media-p1/ff31fe540dca3d898deafc...                  Vans
# ..                                                ...                   ...
# 79  [{'path': 'spp-media-p1/5bbfce2990bf3d5882e608...  MICHAEL Michael Kors
# 80  [{'path': 'spp-media-p1/08e04dc7c7453c7295345b...              Even&Odd
# 81  [{'path': 'spp-media-p1/dec5088239563452b0d97a...             Vero Moda
# 82  [{'path': 'spp-media-p1/2e74e97856ee33029c20d4...               Lacoste
# 83  [{'path': 'spp-media-p1/bfff1851d4613ea9b92db2...           Tommy Jeans
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79        True              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': 'Jusqu’à -25...          shoe
# 1   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 4   [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-30%', 'tra...   accessoires
# 80  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 83  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        99,95 €           74,95 €
# 1                 []        99,95 €           69,95 €
# 2                 []       119,95 €           83,95 €
# 3                 []        34,99 €           29,69 €
# 4                 []        84,95 €           76,45 €
# ..               ...            ...               ...
# 79                []       194,95 €          136,95 €
# 80                []        24,99 €           22,49 €
# 81                []        39,99 €           35,99 €
# 82                []        89,95 €           62,95 €
# 83                []        99,95 €           74,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits amount price.base_price
# 0                                                 NaN    NaN              NaN
# 1                                                 NaN    NaN              NaN
# 2                                                 NaN    NaN              NaN
# 3                                                 NaN    NaN              NaN
# 4   [{'id': 'Fjt8J_KKSKq', 'url_key': '/outfits/Fj...    NaN              NaN
# ..                                                ...    ...              ...
# 79                                                NaN    NaN              NaN
# 80                                                NaN    NaN              NaN
# 81                                                NaN    NaN              NaN
# 82                                                NaN    NaN              NaN
# 83                                                NaN    NaN              NaN
#
# [84 rows x 20 columns]

# %%
total_pages=results['pagination']['page_count']

df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=={k}&sort=popularity'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

#df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-93f00a51e1cd> in <module>
#       5     k=84*i
#       6     url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=={k}&sort=popularity'
# ----> 7     response = urllib.request.urlopen(url)
#       8     results = json.load(response)
#       9     flattened_data = json_normalize(results)
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

#The trending brand
df.brand_name.value_counts().index[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-5d5315433e36> in <module>
#       2
#       3 #The trending brand
# ----> 4 df.brand_name.value_counts().index[0]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'brand_name'

# %%
#The product(s) with the highest discount
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['product_group']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]

# %%
#The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).
total_origin=df1.groupby(['product_group']).sum().price.original

tota_disc[total_disc]/total_origin[total_origin]
