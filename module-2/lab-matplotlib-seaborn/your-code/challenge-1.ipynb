# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.title("Plot 1")
fig, ax = plt.subplots()
ax.plot(x, z)
plt.title("Plot 1")
# Out:
# Text(0.5, 1.0, 'Plot 1')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title("Plot 1")
plt.subplot(2,2,2)
plt.plot(x,z)
plt.title("Plot 2")
# Out:
# Text(0.5, 1.0, 'Plot 2')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title("Plot 1")
plt.subplot(2,2,2)
plt.plot(x,z)
plt.title("Plot 2")
# Out:
# Text(0.5, 1.0, 'Plot 2')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.title("Plot 1")
# Out:
# Text(0.5, 1.0, 'Plot 1')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2,x, np.exp(x))
axes[0].set_title("Normal scale")
axes[1].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
# Out:
# Text(0.5, 1.0, 'Logarithmic scale (y)')

# %% [markdown]
# # In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
data = pd.read_csv("vehicles.csv")

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
sns.scatterplot(x="Combined MPG", y="Highway MPG",data=data)
# Out:
# <AxesSubplot:xlabel='Combined MPG', ylabel='Highway MPG'>

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
sns.boxplot(x='CO2 Emission Grams/Mile', y='Fuel Type', data=data)
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile', ylabel='Fuel Type'>

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
data["Fuel Barrels/Year"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
data2 = data[["Fuel Type", "City MPG"]]
data2.plot.bar()
plt.xlabel("Fuel Type ")
plt.ylabel("City MPG")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0ed2c3cda500> in <module>
#       1 # your code here
#       2 data2 = data[["Fuel Type", "City MPG"]]
# ----> 3 data2.plot.bar()
#       4 plt.xlabel("Fuel Type ")
#       5 plt.ylabel("City MPG")
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1440             else:
#    1441                 w = self.bar_width / K
# -> 1442                 rect = self._plot(
#    1443                     ax,
#    1444                     self.ax_pos + (i + 0.5) * w,
#
# /usr/local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1371     @classmethod
#    1372     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1373         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1374
#    1375     @property
#
# /usr/local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2492             elif orientation == 'horizontal':
#    2493                 r.sticky_edges.x.append(l)
# -> 2494             self.add_patch(r)
#    2495             patches.append(r)
#    2496
#
# /usr/local/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2036         if p.get_clip_path() is None:
#    2037             p.set_clip_path(self.patch)
# -> 2038         self._update_patch_limits(p)
#    2039         self.patches.append(p)
#    2040         p._remove_method = self.patches.remove
#
# /usr/local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2062                 xys = patch_to_data.transform(xys)
#    2063
# -> 2064             updatex, updatey = patch.get_transform().\
#    2065                 contains_branch_seperately(self.transData)
#    2066             self.update_datalim(xys, updatex=updatex,
#
# /usr/local/lib/python3.8/site-packages/matplotlib/patches.py in get_transform(self)
#     258     def get_transform(self):
#     259         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 260         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     261
#     262     def get_data_transform(self):
#
# /usr/local/lib/python3.8/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     790
#     791     def get_patch_transform(self):
# --> 792         self._update_patch_transform()
#     793         return self._rect_transform
#     794
#
# /usr/local/lib/python3.8/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     773         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     774         self._rect_transform = transforms.BboxTransformTo(bbox)
# --> 775         self._rect_transform += rot_trans
#     776
#     777     def _update_x1(self):
#
# /usr/local/lib/python3.8/site-packages/matplotlib/transforms.py in __add__(self, other)
#    1272         ``C.transform(x) == B.transform(A.transform(x))``.
#    1273         """
# -> 1274         return (composite_transform_factory(self, other)
#    1275                 if isinstance(other, Transform) else
#    1276                 NotImplemented)
#
# /usr/local/lib/python3.8/site-packages/matplotlib/transforms.py in composite_transform_factory(a, b)
#    2455     elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2456         return CompositeAffine2D(a, b)
# -> 2457     return CompositeGenericTransform(a, b)
#    2458
#    2459
#
# /usr/local/lib/python3.8/site-packages/matplotlib/transforms.py in __init__(self, a, b, **kwargs)
#    2292         self._a = a
#    2293         self._b = b
# -> 2294         self.set_children(a, b)
#    2295
#    2296     def frozen(self):
#
# /usr/local/lib/python3.8/site-packages/matplotlib/transforms.py in set_children(self, *children)
#     199             ref = weakref.ref(
#     200                 self, lambda _, pop=child._parents.pop, k=id(self): pop(k))
# --> 201             child._parents[id(self)] = ref
#     202
#     203     def frozen(self):
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x119af4280> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /usr/local/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# /usr/local/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# /usr/local/lib/python3.8/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     276             The enclosing bounding box (in figure pixel coordinates).
#     277         """
# --> 278         bbox = self.get_window_extent(renderer)
#     279         if self.get_clip_on():
#     280             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.8/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     596
#     597     def get_window_extent(self, renderer=None):
# --> 598         return self.get_path().get_extents(self.get_transform())
#     599
#     600     def _convert_xy_units(self, xy):
#
# /usr/local/lib/python3.8/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     601                 xys.append(curve([0, *dzeros, 1]))
#     602             xys = np.concatenate(xys)
# --> 603         return Bbox([xys.min(axis=0), xys.max(axis=0)])
#     604
#     605     def intersects_path(self, other, filled=True):
#
# /usr/local/lib/python3.8/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:
